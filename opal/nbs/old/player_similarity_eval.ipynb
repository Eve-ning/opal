# %% [markdown]
# # Evaluating Player Similarity Predictions
#
# In our previous experiments, our results are not reliable due to our training data crossing with test data!
#
# To simulate what would happen realistically, we need to split train and test data before we start our similarity pairing & prediction.

# %%
import pickle
import warnings
from pathlib import Path

from opal.score.dataset import Dataset
from opal.score.preprocessing_dynamic import PreprocessingDynamic
from opal.score.similarity.similarity_eval import similarity_model_eval, plot_eval

if True:
    # PyCharm linting keeps wrecking this import, so it's in a True cond
    pass

warnings.filterwarnings('ignore')

data_path = Path("../../data/osu/scores/")

df = PreprocessingDynamic(
    Dataset(data_path, "top1k").joined_filtered_df,
    unpopular_maps_thres=0,
    unpopular_plays_thres=0,
    sr_min_thres=2.5,
    acc_filter=(0.8, 1),
    score_filter=None
).filter(calc_acc=True)
df_eval, sim = similarity_model_eval(df, 2, 0)
# Out:
# by_score_year 887452 -> 541019
# by_sr 541019 -> 481548
# by_unpopular_maps 481548 -> 481548
# by_unpopular_plays 481548 -> 481548
# by_acc_filter 481548 -> 481516
# by_remove_mod 481516 -> 353211
# Users Left: 992 | Beatmaps Left: 3757
# Fitting Similarity Pair: 100%|██████████| 3430890/3430890 [1:04:15<00:00, 889.94it/s]
# Predicting Scores:  83%|████████▎ | 146261/176606 [1:37:38<20:15, 24.97it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 25>()
#      15 data_path = Path("../../data/osu/scores/")
#      17 df = PreprocessingDynamic(
#      18     Dataset(data_path, "top1k").joined_filtered_df,
#      19     unpopular_maps_thres=0,
#    (...)
#      23     score_filter=None
#      24 ).filter(calc_acc=True)
# ---> 25 df_eval, sim = similarity_model_eval(df, 2, 0)
#
# File D:\Repositories\PycharmProjects\opal\opal\score\similarity\similarity_eval.py:37, in similarity_model_eval(df_score, k_folds, k_fold_seed, **sim_kwargs)
#      33 for ix, test_score in tqdm(test_df.iterrows(),
#      34                            total=len(test_df),
#      35                            desc="Predicting Scores"):
#      36     try:
# ---> 37         pred = sim.predict(
#      38             test_score['user_id'],
#      39             test_score['year'],
#      40             test_score['map_id']
#      41         )
#      42     except (ZeroDivisionError, Exception):
#      43         continue
#
# File D:\Repositories\PycharmProjects\opal\opal\score\similarity\similarity.py:131, in SimilarityModel.predict(self, user_id, year, map_id)
#     128 ix = (user_id, year)
#     129 # We find the df of scores with similarities associated with
#     130 # user_id & year
# --> 131 df = pd.merge(
#     132     # User Scores
#     133     self.params.df_scores,
#     134     # Similarities associated with ix
#     135     self.params.df_sim.loc[ix].dropna().rename('similarity'),
#     136     left_index=True, right_index=True
#     137 )
#     139 # Get only map_id
#     140 df = df[df['map_id'] == map_id]
#
# File D:\Repositories\PycharmProjects\opal\venv\lib\site-packages\pandas\core\reshape\merge.py:122, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
#     107     op = _MergeOperation(
#     108         left,
#     109         right,
#    (...)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#
# File D:\Repositories\PycharmProjects\opal\venv\lib\site-packages\pandas\core\reshape\merge.py:716, in _MergeOperation.get_result(self)
#     713 if self.indicator:
#     714     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# --> 716 join_index, left_indexer, right_indexer = self._get_join_info()
#     718 llabels, rlabels = _items_overlap_with_suffix(
#     719     self.left._info_axis, self.right._info_axis, self.suffixes
#     720 )
#     722 lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# File D:\Repositories\PycharmProjects\opal\venv\lib\site-packages\pandas\core\reshape\merge.py:953, in _MergeOperation._get_join_info(self)
#     950 right_ax = self.right.axes[self.axis]
#     952 if self.left_index and self.right_index and self.how != "asof":
# --> 953     join_index, left_indexer, right_indexer = left_ax.join(
#     954         right_ax, how=self.how, return_indexers=True, sort=self.sort
#     955     )
#     957 elif self.right_index and self.how == "left":
#     958     join_index, left_indexer, right_indexer = _left_join_on_index(
#     959         left_ax, right_ax, self.left_join_keys, sort=self.sort
#     960     )
#
# File D:\Repositories\PycharmProjects\opal\venv\lib\site-packages\pandas\core\indexes\base.py:216, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     207 @functools.wraps(meth)
#     208 def join(
#     209     self,
#    (...)
#     214     sort: bool = False,
#     215 ):
# --> 216     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     217     if not return_indexers:
#     218         return join_index
#
# File D:\Repositories\PycharmProjects\opal\venv\lib\site-packages\pandas\core\indexes\base.py:4406, in Index.join(self, other, how, level, return_indexers, sort)
#    4403 if self.is_monotonic and other.is_monotonic:
#    4404     if self._can_use_libjoin:
#    4405         # otherwise we will fall through to _join_via_get_indexer
# -> 4406         return self._join_monotonic(other, how=how)
#    4407 else:
#    4408     return self._join_non_unique(other, how=how)
#
# File D:\Repositories\PycharmProjects\opal\venv\lib\site-packages\pandas\core\indexes\base.py:4752, in Index._join_monotonic(self, other, how)
#    4750     join_array, ridx, lidx = other._left_indexer(self)
#    4751 elif how == "inner":
# -> 4752     join_array, lidx, ridx = self._inner_indexer(other)
#    4753 elif how == "outer":
#    4754     join_array, lidx, ridx = self._outer_indexer(other)
#
# File D:\Repositories\PycharmProjects\opal\venv\lib\site-packages\pandas\core\indexes\base.py:347, in Index._inner_indexer(self, other)
#     345 sv = self._get_engine_target()
#     346 ov = other._get_engine_target()
# --> 347 joined_ndarray, lidx, ridx = libjoin.inner_join_indexer(sv, ov)
#     348 joined = self._from_join_target(joined_ndarray)
#     349 return joined, lidx, ridx
#
# KeyboardInterrupt:

# %%
df_eval.to_pickle(f"eval.pkl")

with open("sim_model.pkl", "wb+") as f:
    pickle.dump(sim, f)

# %% [markdown]
# To perform evaluation, we perform a 5-fold validation, 20% test, 80% train.

# %%
import pandas as pd

df_eval = pd.read_pickle("out0.04")
plot_eval(df_eval)
